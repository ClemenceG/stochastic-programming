# %% [markdown]
# ## Install Julia
# Run cell then reload
#
# * Learning: https://julialang.org/learning/
# * Documentation: https://docs.julialang.org/
# * Questions & Discussions:
#   * https://discourse.julialang.org/
#   * http://julialang.slack.com/
#   * https://stackoverflow.com/questions/tagged/julia

# %% [markdown]
# ### Using GPU

# %%
try
    using CUDA
catch
    println("No GPU found.")
else
    run(`nvidia-smi`)
    # Create a new random matrix directly on the GPU:
    M_on_gpu = CUDA.CURAND.rand(2^11, 2^11)
    @btime $M_on_gpu * $M_on_gpu; nothing
end

# %% [markdown]
# # Assignment 1 Question 2
# ` l’aide de la librairie StochasticPrograms.jl, r ́esolvez num ́eriquement le probl`eme comme un programme stochastique `a deux  ́etapes, en faisant varier le nombre de sc ́enarios, tir ́es al ́eatoirement, de 5 `a 10000. Plus pr ́ecis ́ement, on demande de consid ́erer 5, 10, 100, 1000 et 10000 sc ́enarios.

# %% [markdown]
# Solving the following stochastic program:
#
# \begin{align*}
#     \min_{x} \quad & 2 x + E_ξ[Q(x,ξ)] \\
#     \mbox{s.t. } & x \geq 0 \\
# \end{align*}
# where
# \begin{align*}
# Q(x,ξ) = \min_y\ & \xi y \\
# \mbox{s.t. } & y \geq 1-x \\
#              &y \geq 0 \\
# \end{align*}
# with
# \begin{align*}
# p_{\xi}(1) = 3/4 \qquad p_{\xi}(3) = 3/4
# \end{align*}

# %%
import Pkg
Pkg.add("StochasticPrograms")
Pkg.add("HiGHS")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
using StochasticPrograms
using HiGHS

# %%
using BenchmarkTools

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Defining the stochastic program

# %% [markdown]
# Generating scenarios __CHECK RAND GENERATOR__

# %%
function generate_scenarios(num_scenarios, min_scenario=5, max_scenario=10000)
    prob = 1/num_scenarios
    scenarios = [@scenario ξ = rand(min_scenario:max_scenario) probability = prob for _ in 1:num_scenarios]
    return scenarios
end
# Out:
# generate_scenarios (generic function with 3 methods)

# %% [markdown]
# ## Question 1 - Model

# %%
@stochastic_model q1_model begin

    @stage 1 begin
        @parameters begin
            cost = 2.0
            up_bound = 10000.0
        end
        @decision(q1_model, x >= 0)   # equivalent to @variable
        @constraint(q1_model, x <= up_bound)
        @objective(q1_model, Min, cost*x)
    end
    @stage 2 begin
        @uncertain ξ
        @recourse(q1_model,  y >= 0)   # equivalent to @decision
        @objective(q1_model, Min, ξ*y)
        @constraint(q1_model,  y >= 1-x)
    end
end
# Out:
# Two-Stage Stochastic Model
#
# minimize f₀(x) + 𝔼[f(x,ξ)]
#   x∈𝒳
#
# where
#
# f(x,ξ) = min  f(y; x, ξ)
#               y ∈ 𝒴 (x, ξ)

# %% [markdown]
# ## Newsvendor Model - Birge et Louveaux

# %%
@stochastic_model simple_model begin
    @stage 1 begin
        @decision(simple_model, x >= 0)
        @objective(simple_model, Min, 0*x)
    end
    @stage 2 begin
        @known(simple_model, x)
        @uncertain ξ
        @recourse(simple_model, 0 <= y[i in 1:2])
        @objective(simple_model, Min, y[1] + y[2])
        @constraint(simple_model, y[1] - y[2] == ξ - x)
    end
end

# %%
function avg_y(model, nb_scenarios)
    optimal_y = model[2,:y]
    y_list = [value(optimal_y, i) for i in 1:nb_scenarios]
    y = sum(y_list)
    return y/nb_scenarios
end
# Out:
# avg_y (generic function with 1 method)

# %% [markdown]
# ## Optimize Model for 5 Scenarios

# %%
res = Vector{Vector{Float64}}()
nb_scenarios = [5, 10, 100, 1000, 10000]
model  =
for n in nb_scenarios
    memory_used = @allocated begin

        ξ = generate_scenarios(n)

        ## LShape
        q2_highs = instantiate(q1_model, ξ, optimizer = LShaped.Optimizer)
        set_optimizer_attribute(q2_highs, MasterOptimizer(), HiGHS.Optimizer)
        set_optimizer_attribute(q2_highs, SubProblemOptimizer(), HiGHS.Optimizer)
        optimize!(q2_highs)
    end

    # Check the status of the optimization
    status = termination_status(q2_highs)

    if status == MOI.OPTIMAL
        # Retrieve the optimal solution
        optimal_objective = objective_value(q2_highs)
        optimal_x = optimal_decision(q2_highs)[1]
        avg_optimal_y =  avg_y(q2_highs, n)

        # Retrieve the runtime
        runtime = q2_highs.:optimizer.:optimizer.:solve_time

        # Store the results
        curr_res = [n, optimal_x, optimal_objective, avg_optimal_y, runtime, memory_used]
        push!(res, curr_res)

    else
        println("Optimization did not converge to an optimal solution.")
    end

end
# Out:
# L-Shaped Gap  (thresh = 1e-06, value = 0.9999)
#   Objective:       20000.0
#   Gap:             0.9998999999999951
#   Number of cuts:  10
#   Iterations:      2
# L-Shaped Gap  Time: 0:00:00 (3 iterations)
#   Objective:       2.0
#   Gap:             0.0
#   Number of cuts:  10
#   Iterations:      3
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.1817390426e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.7269599022e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.1769111318e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.3755869332e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.2923971335e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 1 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-6); columns 0(-6); elements 0(-11) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     : -5.1260871400e+07
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.8418274641e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.8876408669e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -4.9005495230e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -9.8501097195e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -5.1605261673e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -5.1260870624e+07 Pr: 5(7.53212e+06) 0s
#           5     2.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 5
# Objective value     :  2.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  2.0000000000e+00
# HiGHS run time      :          0.00
# Optimal Solution: 5
# x* = 1.0
# Objective Value = 2.0
# avg_optimal_y0.0
# runtime0.02350020408630371
# 917032
# Int64Float64Float64
# y Float64
# Float64
# Int64
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.5872271220e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.1428994736e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.3077919978e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.3274207423e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.2332765371e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.0097301547e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.6348844548e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.9350142888e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.8943219944e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.3960051602e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 1 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-11); columns 0(-11); elements 0(-21) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     : -6.5465450800e+07
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -8.8232002293e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -1.8048308721e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -9.9610999568e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -9.9920972309e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -8.2642496394e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.1737056223e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -2.5817595876e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -3.0557163577e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -9.3081574443e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -8.5212269099e+07 Pr: 1(9999) 0s
#           1     0.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 1
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0    -6.5465449778e+07 Pr: 10(1.06093e+07) 0s
#          10     2.0000000000e+00 Pr: 0(0) 0s
# Model   status      : Optimal
# Simplex   iterations: 10
# Objective value     :  2.0000000000e+00
# HiGHS run time      :          0.00
# L-Shaped Gap  (thresh = 1e-06, value = 0.9999)
#   Objective:       20000.0
#   Gap:             0.9998999999999951
#   Number of cuts:  20
#   Iterations:      2
# L-Shaped Gap  Time: 0:00:00 (3 iterations)
#   Objective:       2.0
#   Gap:             0.0
#   Number of cuts:  20
#   Iterations:      3
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Solving LP without presolve or with basis
# Model   status      : Optimal
# Objective value     :  2.0000000000e+00
# HiGHS run time      :          0.00
# Optimal Solution: 10
# x* = 1.0
# Objective Value = 2.0
# avg_optimal_y0.0
# runtime0.027155160903930664
# 1675072
# Int64Float64Float64
# y Float64
# Float64
# Int64
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.3173416259e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.7950785570e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.5115239142e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.5909832395e+01
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.5116891393e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.4210569733e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.8056008686e+01
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.5564321201e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.2850829153e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.0950413873e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.4899423691e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.2484562301e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.7516470058e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.4774064809e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.2796307255e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.2219697884e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.3259535968e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.7767704001e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.8520889650e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.1741186445e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.6814501805e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.6457012387e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.4234526181e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.0706821293e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.9556907053e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.1493257004e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.8487639589e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.2189752324e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.7497366650e+01
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.0595092886e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.4271596923e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.9070754251e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.0608723361e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.8471840684e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.7620557102e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.2333078542e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.0228309854e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.6890811720e+01
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.8175894635e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.1367898122e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.5904359463e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.1189669593e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.9280580591e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.2852997584e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.4022531411e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.8291959903e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.4974081356e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.3135829337e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.2661138580e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.2588133166e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.0235951217e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.0162945804e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.7163833680e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.4177319672e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.1662191920e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.5352326431e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.1083414118e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.4748456111e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.8458210209e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.5998120535e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.4283058967e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.1744490947e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.7650502661e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.2752731221e+01
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.4242683723e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.1996241069e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.7548584047e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.4419260001e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.4295553371e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.7216703328e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.9986885705e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.5290163170e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# ...
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.0639377042e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.4926538630e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.6493938056e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.6192696106e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.3464909950e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.0842558477e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.4117488821e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.6982671821e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.5375039384e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.1049124386e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.0026134500e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.4661876059e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.8913691013e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.3927845278e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.1396785373e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.9425824630e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.1569842614e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.5952912989e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.6669438484e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.0587130343e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.5132813079e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  5.7106866835e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.0808130826e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  3.9441178187e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.7674295561e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.8143372312e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  8.5853955793e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  9.2072450335e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  6.7736404219e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.2234726632e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  2.8037018646e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  7.8731735400e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.6284279134e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.4330509914e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  4.5078706112e+02
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.9727044278e+03
# HiGHS run time      :          0.00
# Running HiGHS 1.5.3 [date: 1970-01-01, git hash: 45a127b78]
# Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 0 rows, 0 cols, 0 nonzeros
# 0 rows, 0 cols, 0 nonzeros
# Presolve : Reductions: rows 0(-2); columns 0(-2); elements 0(-3) - Reduced to empty
# Solving the original LP from the solution after postsolve
# Model   status      : Optimal
# Objective value     :  1.9296698635e+03
# HiGHS run time      :          0.00
# Copyright (c) 2023 HiGHS under MIT licence terms
# L-Shaped Gap  (thresh = 1e-06, value = 0.9999)
#   Objective:       20000.0
#   Gap:             0.9998999999999951
#   Number of cuts:  20000
#   Iterations:      2
# Excessive output truncated after 535981 bytes.

# %%
res
# Out:
# 5-element Vector{Vector{Float64}}:
#  [5.0, 1.0, 2.0, 0.0, 0.02350020408630371, 917032.0]
#  [10.0, 1.0, 2.0, 0.0, 0.027155160903930664, 1.675072e6]
#  [100.0, 1.0, 2.0, 0.0, 0.18802118301391602, 1.4733096e7]
#  [1000.0, 1.0, 2.0, 0.0, 1.7047138214111328, 1.65516536e8]
#  [10000.0, 1.0, 2.0, 0.0, 28.17290496826172, 3.459218288e9]
